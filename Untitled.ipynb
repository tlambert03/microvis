# %%
from microvis import imshow, ortho
from skimage.data import cells3d
data = cells3d()[:, 0]

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
v = imshow(data)
v
# Out:
# RFBOutputContext()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 v = imshow(data)
#       2 v
#
# File ~/dev/self/microvis/src/microvis/core.py:17, in imshow(data, background_color)
#      15 else:
#      16     scene.visuals.Volume(np.transpose(data, (-1, 0, 1)), parent=view.scene)
# ---> 17     view.camera = scene.ArcballCamera(fov=0, azimuth=0, elevation=0)
#      19 view.camera.set_range()
#      20 return viewer
#
# File ~/mambaforge/envs/all/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py:51, in ArcballCamera.__init__(self, fov, distance, translate_speed, **kwargs)
#      50 def __init__(self, fov=45.0, distance=None, translate_speed=1.0, **kwargs):
# ---> 51     super(ArcballCamera, self).__init__(fov=fov, **kwargs)
#      53     # Set camera attributes
#      54     self._quaternion = Quaternion()
#
# ...

# %%
v = ortho(data)
v
# Out:
# RFBOutputContext()
# <div class='initial-snapshot-b694c9008d1e41d3b169422c24ba69cf' style='position:relative;'><img src='data:image/png;base64,...' style='width:500.0px;height:500.0px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>initial snapshot</div></div>
# CanvasBackend(css_height='500px')

# %%
v.canvas.size = (800, 800)
