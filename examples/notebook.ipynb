# %%
from microvis import imshow
from imageio.v3 import imread

astronaut = imread("imageio:astronaut.png")
immunohistochemistry = imread("imageio:immunohistochemistry.png")
stent = imread("imageio:stent.npz")
camera = imread("imageio:camera.png")

# %%
imshow(astronaut)
# Out:
# RFBOutputContext()
# <div class='initial-snapshot-6297ce5118604740a677416e9d75075e' style='position:relative;'><img src='data:image/png;base64,...' style='width:500.0px;height:500.0px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>initial snapshot</div></div>
# CanvasBackend(css_height='500px')

# %%
imshow(immunohistochemistry)
# Out:
# RFBOutputContext()
# <div class='initial-snapshot-1716b9e9cefa481ba939689287491f83' style='position:relative;'><img src='data:image/png;base64,...' style='width:500.0px;height:500.0px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>initial snapshot</div></div>
# CanvasBackend(css_height='500px')

# %%
imshow(camera)
# Out:
# RFBOutputContext()
# <div class='initial-snapshot-98e916ac4509462aa9b17ebab6ef26fc' style='position:relative;'><img src='data:image/png;base64,...' style='width:500.0px;height:500.0px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>initial snapshot</div></div>
# CanvasBackend(css_height='500px')
