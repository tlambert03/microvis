# %%
from microvis import imshow
from imageio.v3 import imread

astronaut = imread("imageio:astronaut.png")
immunohistochemistry = imread("imageio:immunohistochemistry.png")
stent = imread("imageio:stent.npz")
camera = imread("imageio:camera.png")

# %%
imshow(astronaut)
# Out:
# RFBOutputContext()
# <div class='initial-snapshot-72a3eb8bffb44837bab12303e4132465' style='position:relative;'><img src='data:image/png;base64,...' style='width:500.0px;height:500.0px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>initial snapshot</div></div>
# CanvasBackend(css_height='500px')

# %%
imshow(immunohistochemistry)
# Out:
# RFBOutputContext()
# <div class='initial-snapshot-ebfb6bdf38ec4399aad7a7371e65914a' style='position:relative;'><img src='data:image/png;base64,...' style='width:500.0px;height:500.0px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>initial snapshot</div></div>
# CanvasBackend(css_height='500px')

# %%
imshow(camera)
# Out:
# RFBOutputContext()
# <div class='initial-snapshot-1189f6c9c76e48e7a922727198c33d83' style='position:relative;'><img src='data:image/png;base64,...' style='width:500.0px;height:500.0px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>initial snapshot</div></div>
# CanvasBackend(css_height='500px')
