# %%
from microvis import imshow
from imageio.v3 import imread

astronaut = imread("imageio:astronaut.png")
immunohistochemistry = imread("imageio:immunohistochemistry.png")
stent = imread("imageio:stent.npz")
camera = imread("imageio:camera.png")

# %%
imshow(astronaut)
# Out:
# RFBOutputContext()
# <div class='initial-snapshot-793e6d907d13440080c498622b4df77f' style='position:relative;'><img src='data:image/png;base64,...' style='width:500.0px;height:500.0px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>initial snapshot</div></div>
# CanvasBackend(css_height='500px')

# %%
imshow(immunohistochemistry)
# Out:
# RFBOutputContext()
# <div class='initial-snapshot-36333ba1b6a74146b4f3df117b4d9a96' style='position:relative;'><img src='data:image/png;base64,...' style='width:500.0px;height:500.0px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>initial snapshot</div></div>
# CanvasBackend(css_height='500px')

# %%
imshow(camera)
# Out:
# RFBOutputContext()
# <div class='initial-snapshot-8566b9c18974458ba9e95858aee09aa4' style='position:relative;'><img src='data:image/png;base64,...' style='width:500.0px;height:500.0px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>initial snapshot</div></div>
# CanvasBackend(css_height='500px')
